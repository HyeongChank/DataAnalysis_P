# %%
import pandas as pd
import numpy as np

from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

from xgboost import XGBClassifier
from xgboost import plot_importance

import matplotlib.pyplot as plt
import seaborn as sns

# %%
excel_file = pd.ExcelFile("../data/(기본조사)2022 기업체장애인고용실태조사.xlsx")
train_df = excel_file.parse('Sheet1')
print("행 수:", train_df.shape[0])
print("열 수:", train_df.shape[1])
# Out:
# 행 수: 30530
# 열 수: 88

# %%
print(train_df.head())
# Out:
#        ID       WT_B    D_RES                           DIS_CODE
# 0    일련번호   기본조사 가중치  심층조사 완료  [분석변수(가공)] 장애인고용여부(기본조사 DIS_T 가공)  \
# 1  100001  17.051362   #NULL!                                  2
# 2  100002  73.871586   #NULL!                                  2
# 3  100006  17.051362        1                                  1
# 4  100010   3.779508        1                                  1
#
#                                       RATE
# 0  [분석변수(가공)] 장애인고용률(기본조사 DIS_T/EMP_T*100)  \
# 1                                        0
# 2                                        0
# 3                                16.666667
# 4                                 3.571429
#
#                                        R_RATE                     INDUSTRY
# 0  [분석변수(가공)] 장애인고용률 수준(기본조사 DIS_T/EMP_T*100)  [분석변수(가공)] 업종(기본조사 A3_1 가공)  \
# 1                                           1                            1
# 2                                           1                            3
# 3                                           5                            1
# 4                                           5                            4
#
#                          DISTRICT                          SCALE
# 0  [분석변수(가공)] 본사소재 지역(기본조사 A5 가공)  [분석변수(가공)] 종사자 규모(기본조사 B9 가공)  \
# 1                               1                              3
# 2                               3                              1
# 3                               1                              2
# 4                               1                              2
#
#                                 DUTY  ...                DIS7_F
# 0  [분석변수(가공)] 고용의무기업체 여부(기본조사 B9 가공)  ...  [B10. 장애인현황] 7 정신(여)  \
# 1                                  2  ...                     0
# 2                                  1  ...                     0
# 3                                  1  ...                     0
# 4                                  1  ...                     0
#
#                   DIS8_F                DIS9_F                DIS10_F
# 0  [B10. 장애인현황] 8 자폐성(여)  [B10. 장애인현황] 9 신장(여)  [B10. 장애인현황] 10 심장(여)  \
# 1                      0                     0                      0
# 2                      0                     0                      0
# 3                      0                     0                      0
# 4                      0                     0                      0
#
#                   DIS11_F               DIS12_F                DIS13_F
# 0  [B10. 장애인현황] 11 호흡기(여)  [B10. 장애인현황] 12 간(여)  [B10. 장애인현황] 13 안면(여)  \
# 1                       0                     0                      0
# 2                       0                     0                      0
# 3                       0                     0                      0
# 4                       0                     0                      0
#
#                    DIS14_F                 DIS15_F                 DIS16_F
# 0  [B10. 장애인현황] 14 장루요루(여)  [B10. 장애인현황] 15 뇌전증(여)  [B10. 장애인현황] 16 유공자(여)
# 1                        0                       0                       0
# 2                        0                       0                       0
# 3                        0                       0                       0
# 4                        0                       0                       0
#
# [5 rows x 88 columns]

# %%
print(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30530 entries, 0 to 30529
# Data columns (total 88 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        30530 non-null  object
#  1   WT_B      30530 non-null  object
#  2   D_RES     30530 non-null  object
#  3   DIS_CODE  30530 non-null  object
#  4   RATE      30530 non-null  object
#  5   R_RATE    30530 non-null  object
#  6   INDUSTRY  30530 non-null  object
#  7   DISTRICT  30530 non-null  object
#  8   SCALE     30530 non-null  object
#  9   DUTY      30530 non-null  object
#  10  CHARGE    30530 non-null  object
#  11  ORGTYPE   30530 non-null  object
#  12  ORGTYPE2  30530 non-null  object
#  13  YEAR      30530 non-null  object
#  14  YEAR0     30530 non-null  object
#  15  a2        30530 non-null  object
#  16  a3        30530 non-null  object
#  17  a3_1_L    30530 non-null  object
#  18  a3_1_M    30530 non-null  object
#  19  a3_1_S    30530 non-null  object
#  20  a4        30530 non-null  object
#  21  a4_1      30530 non-null  object
#  22  a5        30530 non-null  object
#  23  a6        30530 non-null  object
#  24  a7_1      30530 non-null  object
#  25  a7_2      30530 non-null  object
#  26  a8_1      30530 non-null  object
#  27  a8_2      30530 non-null  object
#  28  a8_3      30530 non-null  object
#  29  a8_4      30530 non-null  object
#  30  a8_5      30530 non-null  object
#  31  EMP_T     30530 non-null  object
#  32  EMP_M     30530 non-null  object
#  33  EMP_F     30530 non-null  object
#  34  DIS_T     30530 non-null  object
#  35  DIS_M     30530 non-null  object
#  36  DIS_F     30530 non-null  object
#  37  DIS0_T    30530 non-null  object
#  38  DIS1_T    30530 non-null  object
#  39  DIS2_T    30530 non-null  object
#  40  DIS3_T    30530 non-null  object
#  41  DIS4_T    30530 non-null  object
#  42  DIS5_T    30530 non-null  object
#  43  DIS6_T    30530 non-null  object
#  44  DIS7_T    30530 non-null  object
#  45  DIS8_T    30530 non-null  object
#  46  DIS9_T    30530 non-null  object
#  47  DIS10_T   30530 non-null  object
#  48  DIS11_T   30530 non-null  object
#  49  DIS12_T   30530 non-null  object
#  50  DIS13_T   30530 non-null  object
#  51  DIS14_T   30530 non-null  object
#  52  DIS15_T   30530 non-null  object
#  53  DIS16_T   30530 non-null  object
#  54  DIS0_M    30530 non-null  object
#  55  DIS1_M    30530 non-null  object
#  56  DIS2_M    30530 non-null  object
#  57  DIS3_M    30530 non-null  object
#  58  DIS4_M    30530 non-null  object
#  59  DIS5_M    30530 non-null  object
#  60  DIS6_M    30530 non-null  object
#  61  DIS7_M    30530 non-null  object
#  62  DIS8_M    30530 non-null  object
#  63  DIS9_M    30530 non-null  object
#  64  DIS10_M   30530 non-null  object
#  65  DIS11_M   30530 non-null  object
#  66  DIS12_M   30530 non-null  object
#  67  DIS13_M   30530 non-null  object
#  68  DIS14_M   30530 non-null  object
#  69  DIS15_M   30530 non-null  object
#  70  DIS16_M   30530 non-null  object
#  71  DIS0_F    30530 non-null  object
#  72  DIS1_F    30530 non-null  object
#  73  DIS2_F    30530 non-null  object
#  74  DIS3_F    30530 non-null  object
#  75  DIS4_F    30530 non-null  object
#  76  DIS5_F    30530 non-null  object
#  77  DIS6_F    30530 non-null  object
#  78  DIS7_F    30530 non-null  object
#  79  DIS8_F    30530 non-null  object
#  80  DIS9_F    30530 non-null  object
#  81  DIS10_F   30530 non-null  object
#  82  DIS11_F   30530 non-null  object
#  83  DIS12_F   30530 non-null  object
#  84  DIS13_F   30530 non-null  object
#  85  DIS14_F   30530 non-null  object
#  86  DIS15_F   30530 non-null  object
#  87  DIS16_F   30530 non-null  object
# dtypes: object(88)
# memory usage: 20.5+ MB
# None
